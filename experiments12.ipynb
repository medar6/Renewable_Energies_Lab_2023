# %%
import pvlib

import pandas as pd

import matplotlib.pyplot as plt

import pvlib.pvsystem as pvsystem


# coordinates = [(47.4, 8.54, 'Zurich-ETZ', 550, 'Etc/GMT-1'),(47.4, 8.54, 'Zurich-ETZ', 550, 'Etc/GMT-1')]

sandia_modules = pvlib.pvsystem.retrieve_sam('SandiaMod')

sapm_inverters = pvlib.pvsystem.retrieve_sam('cecinverter')

module = sandia_modules['Canadian_Solar_CS5P_220M___2009_']

inverter = sapm_inverters['ABB__MICRO_0_25_I_OUTD_US_208__208V_']

temperature_model_parameters = pvlib.temperature.TEMPERATURE_MODEL_PARAMETERS['sapm']['open_rack_glass_glass']

# %%
systems = [({'surface_azimuth': 255, 'surface_tilt':50}),
           ({'surface_azimuth': 240,'surface_tilt':35}),
           ({'surface_azimuth': 180,'surface_tilt':30}),
           ({'surface_azimuth': 120,'surface_tilt':35}),
           ({'surface_azimuth': 105,'surface_tilt':50})]


system_names = ["testone", "testtwo"]

# %%
tmys = []

coordinates = []

for x in range(0, len(systems)):
    coordinates.append((47.4, 8.54, 'Zurich-ETZ', 550, 'Etc/GMT+2'))

for location in coordinates:
    latitude, longitude, name, altitude, timezone = location
    weather = pvlib.iotools.get_pvgis_tmy(latitude, longitude,map_variables=True)[0]
    weather.index.name = "utc_time"
    tmys.append(weather)

# %%
energies = {}
names = ['West-Facing Array (255)','West-Facing Array (240)','South-Facing Array (180)','East-Facing Array (120)','East-Facing Array (105)']
i=0

for system, weather, location in zip(systems, tmys, coordinates):
    latitude, longitude, name, altitude, timezone = location
    # system['surface_tilt'] = latitude
    solpos = pvlib.solarposition.get_solarposition(
        time=weather.index,
        latitude=latitude,
        longitude=longitude,
        altitude=altitude,
        temperature=weather["temp_air"],
        pressure=pvlib.atmosphere.alt2pres(altitude),
    )
    dni_extra = pvlib.irradiance.get_extra_radiation(weather.index)
    airmass = pvlib.atmosphere.get_relative_airmass(solpos['apparent_zenith'])
    pressure = pvlib.atmosphere.alt2pres(altitude)
    am_abs = pvlib.atmosphere.get_absolute_airmass(airmass, pressure)
    aoi = pvlib.irradiance.aoi(
        system['surface_tilt'],
        system['surface_azimuth'],
        solpos["apparent_zenith"],
        solpos["azimuth"],
    )
    total_irradiance = pvlib.irradiance.get_total_irradiance(
        system['surface_tilt'],
        system['surface_azimuth'],
        solpos['apparent_zenith'],
        solpos['azimuth'],
        weather['dni'],
        weather['ghi'],
        weather['dhi'],
        dni_extra=dni_extra,
        model='haydavies',
    )
    cell_temperature = pvlib.temperature.sapm_cell(
        total_irradiance['poa_global'],
        weather["temp_air"],
        weather["wind_speed"],
        **temperature_model_parameters,
    )
    effective_irradiance = pvlib.pvsystem.sapm_effective_irradiance(
        total_irradiance['poa_direct'],
        total_irradiance['poa_diffuse'],
        am_abs,
        aoi,
        module,
    )
    dc = pvlib.pvsystem.sapm(effective_irradiance, cell_temperature, module)
    ac = pvlib.inverter.sandia(dc['v_mp'], dc['p_mp'], inverter)
    annual_energy = ac.sum()/365
    energies[names[i]] = annual_energy
    i+=1
    # print("run")


energies = pd.Series(energies)



print(energies)


energies.plot(kind='bar', rot=90)

plt.ylabel('Average Daily energy yield (W hr)')
# plt.width(300)

# energies[0] += energies[1]
# energies_to_plot = {}
# energies_to_plot["Double panels"] = energies[0]+energies[1]
# energies_to_plot["Single panel"] = energies[2]
# energies_to_plot = pd.Series(energies_to_plot)
# print(energies_to_plot)
# energies_to_plot.plot(kind='bar', rot=0)
# Out:
# West-Facing Array (255)     581.026889
# West-Facing Array (240)     657.326362
# South-Facing Array (180)    740.409398
# East-Facing Array (120)     683.016194
# East-Facing Array (105)     615.147552
# dtype: float64
# Text(0, 0.5, 'Average Daily energy yield (W hr)')
